# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# %%
conda install -c anaconda pandas-datareader
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Nguta\anaconda3
#
#   added / updated specs:
#     - pandas-datareader
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.3.29  |       haa95532_1         160 KB  anaconda
#     certifi-2021.10.8          |   py39haa95532_2         156 KB  anaconda
#     openssl-1.1.1n             |       h2bbff1b_0         5.8 MB  anaconda
#     pandas-datareader-0.10.0   |     pyhd3eb1b0_0          71 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         6.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   pandas-datareader  anaconda/noarch::pandas-datareader-0.10.0-pyhd3eb1b0_0 None
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
# ...

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')
from pandas import DataFrame
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame()

# %%
['all_stocks.pickle']
# Out:
# ['all_stocks.pickle']

# %%
import os
os.chdir('C:/Users/Nguta/Desktop')

# %%
start = datetime.datetime(2013,1,1)
end = datetime.datetime(2020,12,12)

# %%
'''
# 2013
2013 = data.DataReader("2013", 'NSE_data_all_stocks_2013', start, end)

# 2014
2014 = data.DataReader("2014", 'NSE_data_all_stocks_2014', start, end)

# 2015
2015 = data.DataReader("2015", 'NSE_data_all_stocks_2015', start, end)

# 2016
2016= data.DataReader("2016", 'NSE_data_all_stocks_2016', start, end)

# 2017
2017 = data.DataReader("2017", 'NSE_data_all_stocks_2017', start, end)

# 2018
2018 = data.DataReader("2018", 'NSE_data_all_stocks_2018', start, end)

# 2019
2019 = data.DataReader("2019", 'NSE_data_all_stocks_2019', start, end)

# 2020
2020 = data.DataReader("2020", 'NSE_data_all_stocks_2020', start, end)

'''
# Out:
# '\n# 2013\n2013 = data.DataReader("2013", \'NSE_data_all_stocks_2013\', start, end)\n\n# 2014\n2014 = data.DataReader("2014", \'NSE_data_all_stocks_2014\', start, end)\n\n# 2015\n2015 = data.DataReader("2015", \'NSE_data_all_stocks_2015\', start, end)\n\n# 2016\n2016= data.DataReader("2016", \'NSE_data_all_stocks_2016\', start, end)\n\n# 2017\n2017 = data.DataReader("2017", \'NSE_data_all_stocks_2017\', start, end)\n\n# 2018\n2018 = data.DataReader("2018", \'NSE_data_all_stocks_2018\', start, end)\n\n# 2019\n2019 = data.DataReader("2019", \'NSE_data_all_stocks_2019\', start, end)\n\n# 2020\n2020 = data.DataReader("2020", \'NSE_data_all_stocks_2020\', start, end)\n\n'

# %%
spreadsheet=pd.read_csv('/Users/Nguta/Desktop/NSE_data_all_stocks_2013.csv')

# %%
spreadsheet.head()
# Out:
#        DATE  CODE                     NAME 12m Low 12m High Day Low Day High  \
# 0  2-Jan-13  EGAD              Eaagads Ltd     8.2       14      25       25
# 1  2-Jan-13  KUKZ               Kakuzi Plc     300    423.5    67.5     67.5
# 2  2-Jan-13  KAPC  Kapchorua Tea Kenya Plc      59       95     118      118
# 3  2-Jan-13  LIMT           Limuru Tea Plc     385      475     430      430
# 4  2-Jan-13  SASN               Sasini Plc    14.8     19.6    11.7    12.05
#
#   Day Price Previous Change Change%  Volume Adjust
# 0        25       25      -       -       -      -
# 1      67.5       72   -4.5   6.25%     300      -
# 2       118      118      -       -       -     59
# 3       430      430      -       -       -    215
# 4      11.9     11.7    0.2   1.71%  14,500      -

# %%
spreadsheet=pd.read_csv('/Users/Nguta/Desktop/NSE_data_all_stocks_2014.csv')

# %%
spreadsheet.head()
# Out:
#         DATE  CODE                     NAME 12m Low 12m High Day Low Day High  \
# 0  02-Jan-14  EGAD              Eaagads Ltd     8.2       14   23.75    23.75
# 1  02-Jan-14  KUKZ               Kakuzi Plc     300    423.5      95       95
# 2  02-Jan-14  KAPC  Kapchorua Tea Kenya Plc      59       95     125      125
# 3  02-Jan-14  LIMT           Limuru Tea Plc     385      475     500      500
# 4  02-Jan-14  SASN               Sasini Plc    14.8       19    14.7       15
#
#   Day Price Previous Change Change%  Volume Adjust
# 0     23.75    23.75      -       -   1,600      -
# 1        95       95      -       -     100      -
# 2       125      125      -       -       -   62.5
# 3       500      500      -       -       -    250
# 4      14.7    14.65   0.05   0.34%  18,600      -

# %%
spreadsheet=pd.read_csv('/Users/Nguta/Desktop/NSE_data_all_stocks_2015.csv')

# %%
spreadsheet.head()
# Out:
#        DATE  CODE                     NAME 12m Low 12m High Day Low Day High  \
# 0  2-Jan-15  EGAD              Eaagads Ltd     8.2       14      42       42
# 1  2-Jan-15  KUKZ               Kakuzi Plc     300    423.5     180      180
# 2  2-Jan-15  KAPC  Kapchorua Tea Kenya Plc      59       95     137      137
# 3  2-Jan-15  LIMT           Limuru Tea Plc     385      475     771      771
# 4  2-Jan-15  SASN               Sasini Plc    14.8     19.6      13       13
#
#   Day Price Previous Change Change% Volume Adjust
# 0        42       42      -       -      -      -
# 1       180      180      -       -  5,200      -
# 2       137      137      -       -      -   68.5
# 3       771      771      -       -      -  385.5
# 4        13    12.85   0.15   1.17%  1,000      -

# %%
spreadsheet=pd.read_csv('/Users/Nguta/Desktop/NSE_data_all_stocks_2016.csv')

# %%
spreadsheet.head()
# Out:
#         DATE  CODE                     NAME 12m Low 12m High   Day Low  \
# 0  04-Jan-16  EGAD              Eaagads Ltd     8.2       14        25
# 1  04-Jan-16  KUKZ               Kakuzi Plc     300    423.5       317
# 2  04-Jan-16  KAPC  Kapchorua Tea Kenya Plc      59       95       200
# 3  04-Jan-16  LIMT           Limuru Tea Plc     385      475  1,085.00
# 4  04-Jan-16  SASN               Sasini Plc    14.8     19.6      19.5
#
#    Day High Day Price  Previous Change Change% Volume Adjust
# 0        25        25     26.75  -1.75   6.54%    400      -
# 1       348       332       317     15   4.73%    200      -
# 2       200       200       200      -       -    800    100
# 3  1,085.00  1,085.00  1,085.00      -       -      -      -
# 4      19.5      19.5     19.55  -0.05   0.26%    700      -

# %%
spreadsheet=pd.read_csv('/Users/Nguta/Desktop/NSE_data_all_stocks_2017.csv')

# %%
spreadsheet.head()
# Out:
#         DATE  CODE                     NAME 12m Low 12m High Day Low Day High  \
# 0  03-Jan-17  EGAD              Eaagads Ltd     8.2       14   27.25       28
# 1  03-Jan-17  KUKZ               Kakuzi Plc     300    423.5     280      280
# 2  03-Jan-17  KAPC  Kapchorua Tea Kenya Plc      59       95      80       80
# 3  03-Jan-17  LIMT           Limuru Tea Plc     385      475     530      530
# 4  03-Jan-17  SASN               Sasini Plc    14.8     19.6    19.2       21
#
#   Day Price Previous Change Change% Volume Adjust
# 0     27.75    27.25    0.5   1.83%  3,500      -
# 1       280      309    -29   9.39%    200      -
# 2        80       80      -       -      -      -
# 3       530      530      -       -    100      -
# 4      19.9     19.2    0.7   3.65%  4,900      -

# %%
spreadsheet=pd.read_csv('/Users/Nguta/Desktop/NSE_data_all_stocks_2018.csv')

# %%
spreadsheet.head()
# Out:
#         DATE  CODE                     NAME 12m Low 12m High Day Low Day High  \
# 0  02-Jan-18  EGAD              Eaagads Ltd     8.2       14      25       25
# 1  02-Jan-18  KUKZ               Kakuzi Plc     300    423.5     329      329
# 2  02-Jan-18  KAPC  Kapchorua Tea Kenya Plc      59       95    67.5       70
# 3  02-Jan-18  LIMT           Limuru Tea Plc     385      475     500      500
# 4  02-Jan-18  SASN               Sasini Plc    14.8     19.6      27     27.5
#
#   Day Price Previous Change Change%  Volume Adjust
# 0        25    22.75   2.25   9.89%  10,500      -
# 1       329      329      -       -       -      -
# 2      67.5     65.5      2   3.05%   1,000      -
# 3       500      500      -       -       -      -
# 4        27     29.5   -2.5   8.47%     300      -

# %%
spreadsheet=pd.read_csv('/Users/Nguta/Desktop/NSE_data_all_stocks_2019.csv')

# %%
spreadsheet.head()
# Out:
#         DATE  CODE                     NAME 12m Low 12m High Day Low Day High  \
# 0  02-Jan-19  EGAD              Eaagads Ltd     8.2       14    14.5     14.5
# 1  02-Jan-19  KUKZ               Kakuzi Plc     300    423.5     310      310
# 2  02-Jan-19  KAPC  Kapchorua Tea Kenya Plc      59       95    74.5     74.5
# 3  02-Jan-19  LIMT           Limuru Tea Plc     385      475     500      500
# 4  02-Jan-19  SASN               Sasini Plc    14.8       19      19       21
#
#   Day Price Previous Change Change% Volume Adjust
# 0      14.5     14.5      -       -      -      -
# 1       310      310      -       -      -      -
# 2      74.5       75   -0.5   0.67%    200      -
# 3       500      500      -       -      -      -
# 4      19.8     19.9   -0.1   0.50%  1,000      -

# %%
spreadsheet=pd.read_csv('/Users/Nguta/Desktop/NSE_data_all_stocks_2020.csv')

# %%
spreadsheet.head()
# Out:
#         DATE  CODE                     NAME 12m Low 12m High Day Low Day High  \
# 0  02-Jan-20  EGAD              Eaagads Ltd     8.2       14    10.1     10.1
# 1  02-Jan-20  KUKZ               Kakuzi Plc     300    423.5     340      340
# 2  02-Jan-20  KAPC  Kapchorua Tea Kenya Plc      59       95      80       80
# 3  02-Jan-20  LIMT           Limuru Tea Plc     385      475     450      450
# 4  02-Jan-20  SASN               Sasini Plc    14.8     19.6   16.15    16.15
#
#   Day Price Previous Change Change% Volume Adjust
# 0      10.1     10.1      -       -      -      -
# 1       340      340      -       -      -      -
# 2        80       80      -       -      -      -
# 3       450      450      -       -      -      -
# 4     16.15     16.9  -0.75   4.44%    300      -

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
returns = pd.DataFrame()

# %%
print(df.dtypes)
# Out:
# Series([], dtype: object)

# %%
df.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
spreadsheet.head(8)
# Out:
#         DATE  CODE                      NAME 12m Low 12m High Day Low  \
# 0  02-Jan-20  EGAD               Eaagads Ltd     8.2       14    10.1
# 1  02-Jan-20  KUKZ                Kakuzi Plc     300    423.5     340
# 2  02-Jan-20  KAPC   Kapchorua Tea Kenya Plc      59       95      80
# 3  02-Jan-20  LIMT            Limuru Tea Plc     385      475     450
# 4  02-Jan-20  SASN                Sasini Plc    14.8     19.6   16.15
# 5  02-Jan-20   WTK  Williamson Tea Kenya Plc      92      165     139
# 6  02-Jan-20  CGEN   Car and General (K) Ltd      20       26      26
# 7  02-Jan-20  ABSA       ABSA Bank Kenya Plc     9.1     14.2    13.2
#
#   Day High Day Price Previous Change Change%  Volume Adjust
# 0     10.1      10.1     10.1      -       -       -      -
# 1      340       340      340      -       -       -      -
# 2       80        80       80      -       -       -      -
# 3      450       450      450      -       -       -      -
# ...

# %%
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm
import statsmodels.tsa.api as smt
import statsmodels.formula.api as smf

# %%
from sklearn.metrics import mean_squared_error

# %%
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
import pickle

# take user input to take the amount of data
number_of_data = int(input('Enter the number of data : '))
data = []

# take input of the data
for i in range(number_of_data):
    raw = input('Enter data '+str(i)+' : ')
    data.append(raw)

# open a file, where you ant to store the data
file = open('important', 'wb')

# dump information to that file
pickle.dump(data, file)

# close the file
file.close()
# Out:
# Enter the number of data : 8
# Enter data 0 : 2013
# Enter data 1 : 2014
# Enter data 2 : 2015
# Enter data 3 : 2016
# Enter data 4 : 2017
# Enter data 5 : 2018
# Enter data 6 : 2019
# Enter data 7 : 2020

# %%
print (df.describe)
# Out:
# <bound method NDFrame.describe of Empty DataFrame
# Columns: []
# Index: []>

# %%
print ("=============================================================")
print (df.dtypes)
# Out:
# ...
# Series([], dtype: object)

# %%
returns = pd.DataFrame()

# %%
df.xs(key='DATE',axis=1,level='Day High').max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [128], in <cell line: 1>()
# ----> 1 df.xs(key='DATE',axis=1,level='Day High').max()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:3835, in NDFrame.xs(self, key, axis, level, drop_level)
#    3833 if level is not None:
#    3834     if not isinstance(labels, MultiIndex):
# -> 3835         raise TypeError("Index must be a MultiIndex")
#    3836     loc, new_ax = labels.get_loc_level(key, level=level, drop_level=drop_level)
#    3838     # create the tuple of the indexer
#
# TypeError: Index must be a MultiIndex
